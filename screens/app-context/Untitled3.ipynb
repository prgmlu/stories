# %%
import json

# %%
a = json.loads(open('initialVocab.json').read())

# %%
json.dump(a,open('initialVocab.json','w'),indent=2,ensure_ascii=False)

# %%
from collections import Counter

# %%
Counter(['1','2','1'])
# Out:
# Counter({'1': 2, '2': 1})

# %%
Counter(open('../story/context/story-context.js').read().split()).most_common()
# Out:
# [('of', 41),
#  ('is', 41),
#  ('meaning', 41),
#  ("?',", 41),
#  ('the', 41),
#  ("'the", 41),
#  ("'s',", 38),
#  ("'What", 31),
#  ("['في'],", 21),
#  ("'my", 19),
#  ("['يا'],", 19),
#  ('//', 19),
#  ("'to", 18),
#  ("['إلى'],", 18),
#  ("[['الأب:'],", 16),
#  ("['من'],", 15),
#  ("'and", 14),
#  ("'I", 13),
#  ("[['مصطفى:'],", 13),
#  ("need',", 13),
#  ("[['الأم:'],", 12),
#  ("['أحتاج'],", 11),
#  ("'i", 11),
#  ("'this',", 10),
#  ("['هذا'],", 10),
#  ('=', 10),
#  ("[['مروة:'],", 9),
#  ('2,', 9),
#  ('const', 9),
#  ("['What", 9),
#  ('3,', 8),
#  ("'in',", 8),
#  ("'very',", 8),
#  ("have',", 8),
#  ("[['منة:'],", 8),
#  ("['أن'],", 8),
#  ('4,', 8),
#  ("'to',", 8),
#  ("[['أيمن:'],", 7),
#  ("'في':", 7),
#  ("['ولكن'],", 7),
#  ("[['محمد:'],", 7),
#  ("'o',", 7),
#  ("'إلى':", 7),
#  ("[['سلمى:'],", 7),
#  ("[['عمر:'],", 7),
#  ("'يا':", 7),
#  ('{', 7),
#  ("'you", 7),
#  ("['أنا'],", 6),
#  ("[['أحمد:'],", 6),
#  ("'من':", 6),
#  ("is',", 6),
#  ("['المتجر:'],", 6),
# ...
